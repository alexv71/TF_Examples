# %% [markdown]
# <a href="https://colab.research.google.com/github/alexv71/TF_Examples/blob/master/colab_test1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
